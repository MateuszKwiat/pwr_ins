# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ts = pd.read_csv('amz.csv')
ts = ts.set_index('Date')

ts.head(10)
# Out:
#                Open     High      Low    Close  Adj Close     Volume
# Date
# 2014-12-31  15.5775  15.6490  15.5005  15.5175    15.5175   40960000
# 2015-01-02  15.6290  15.7375  15.3480  15.4260    15.4260   55664000
# 2015-01-05  15.3505  15.4190  15.0425  15.1095    15.1095   55484000
# 2015-01-06  15.1120  15.1500  14.6190  14.7645    14.7645   70380000
# 2015-01-07  14.8750  15.0640  14.7665  14.9210    14.9210   52806000
# 2015-01-08  15.0160  15.1570  14.8055  15.0230    15.0230   61768000
# 2015-01-09  15.0740  15.1435  14.8340  14.8465    14.8465   51848000
# 2015-01-12  14.8780  14.9255  14.4640  14.5705    14.5705   68428000
# 2015-01-13  14.8740  15.0750  14.6615  14.7370    14.7370   82728000
# 2015-01-14  14.5965  14.7955  14.3250  14.6635    14.6635  110774000

# %%
ts.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
ts.isnull().sum().sum()
# Out:
# 0

# %%
ts.isna().sum().sum()
# Out:
# 0

# %%
ts.shape
# Out:
# (2331, 6)

# %%
fig, ax = plt.subplots(figsize=(14, 7))

ax.plot(np.arange(2331), ts['Close'], color='orange')
ax.set_title('Amazon closing stock price in time')
ax.grid()

plt.show()

# %%
print('mean: {0:.2f}, standard deviation: {1:.2f}, minimum: {2:.2f}, maximum: {3:.2f}'
      .format(np.mean(ts['Close']), np.std(ts['Close']), np.min(ts['Close']), np.max(ts['Close'])))
# Out:
# mean: 94.07, standard deviation: 49.63, minimum: 14.35, maximum: 186.57
