# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('appartments.csv')

X = df.drop('price', axis=1)
Y = df['price']

# %%
print(f'X data frame:\n{X}')
print(f'\nY data frame:\n{Y}')
# Out:
# X data frame:
#     area  rooms  floor  year_of_construction
# 0     61      1      6                  1962
# 1     87      4      6                  1984
# 2     78      1      5                  2007
# 3     86      2      8                  1963
# 4    105      3      2                  1955
# ..   ...    ...    ...                   ...
# 95    90      3      6                  1968
# 96    60      3      9                  2004
# 97    85      1      4                  2018
# 98    85      4      1                  2011
# 99    86      2      6                  1997
#
# [100 rows x 4 columns]
#
# Y data frame:
# 0     561899
# 1     237517
# 2     655949
# 3     330271
# 4     424981
#        ...
# 95    473247
# 96    457462
# 97    424272
# 98    448460
# 99    496029
# Name: price, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(f'X train data:\n{x_train.head(5)}')
print(f'\nX train data shape:\n{x_train.shape}')
print(f'\nX test data:\n{x_test.head(5)}')
print(f'\nX test data shape:\n{x_test.shape}')
# Out:
# X train data:
#     area  rooms  floor  year_of_construction
# 55    78      3      6                  1971
# 88    70      2      1                  1994
# 26    97      1      8                  1954
# 42    76      2      6                  1992
# 69   101      4      7                  1977
#
# X train data shape:
# (80, 4)
#
# X test data:
#     area  rooms  floor  year_of_construction
# 83    50      2      2                  2012
# 53    79      3      1                  1962
# 70    93      4      3                  1969
# 45    82      4      5                  2007
# 44    83      4      6                  2008
#
# X test data shape:
# (20, 4)

# %%
print(f'Y train data:\n{y_train.head(5)}')
print(f'\nY train data shape:\n{y_train.shape}')
print(f'\nY test data:\n{y_test.head(5)}')
print(f'\nY test data shape:\n{y_test.shape}')
# Out:
# Y train data:
# 55    403209
# 88    751114
# 26    770655
# 42    306130
# 69    428415
# Name: price, dtype: int64
#
# Y train data shape:
# (80,)
#
# Y test data:
# 83    891210
# 53    482016
# 70    550223
# 45    600778
# 44    861691
# Name: price, dtype: int64
#
# Y test data shape:
# (20,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = linear_model.predict(X)

# %%
print(f'Model mean square error: {mean_squared_error(Y, y_prediction)}')
print(f'\nModel r2 score: {r2_score(Y, y_prediction)}')
# Out:
# Model mean square error: 51727820123.83028
#
# Model r2 score: 0.04779944671979597

# %%
fig, ax = plt.subplots()

ax.scatter(X['area'], Y, color='blue', label='original data')
ax.scatter(X['area'], y_prediction, color='red', label='predictions')

ax.set_xlabel('area')
ax.set_ylabel('price')
ax.legend()

plt.show()
